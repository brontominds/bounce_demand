# %%
import pandas as pd
from sklearn.utils import shuffle

# %%
data=pd.read_csv("train.csv")#Making it Relative Path -Mayank
data_ori=data.copy()

# %%
import matplotlib.pyplot as plt  # For plotting graphs 
from datetime import datetime    # To access datetime 
        
# %matplotlib inline

# %%
data.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
def datetime(df):
  from datetime import datetime
  df['datetime'] = pd.to_datetime(df['datetime'])
  df['year'] = df['datetime'].dt.year 
  df['day'] = df['datetime'].dt.day 
  df['hour'] = df['datetime'].dt.hour
  return df

# %%
data_ori=datetime(data_ori)

# %%
data_ori=data_ori.drop('datetime',axis=1)

# %%
def normalize(df,columns):
    result=df.copy()
    for feature_name in columns :
        mean_value = df[feature_name].mean()
        std_value = df[feature_name].std()
        result[feature_name] = (df[feature_name] - mean_value) / std_value
        
    return result

# %%
data_ori=normalize(data_ori,["temp","atemp","humidity","windspeed"])

# %%
def dummy_data(data, columns):
    for column in columns:
        data = pd.concat([data, pd.get_dummies(data[column], prefix=column)], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
data_ori = dummy_data(data_ori, ["season","weather","hour"])

# %%
data_ori.shape
# Out:
# (10886, 43)

# %%
data=shuffle(data_ori)
nrows = len(data_ori)
training_validation_rows = int(nrows*0.8)
data=data_ori[0:training_validation_rows-1]
test1=data_ori[training_validation_rows:]

# %%
data.shape
# Out:
# (8707, 43)

# %%
test1.shape
# Out:
# (2178, 43)

# %%
import seaborn as sns

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['temp']); 
plt.subplot(122)
data['temp'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.scatter(data['temp'],data['count'],alpha=0.1,
            cmap='viridis')

# %%
data['temp'].describe()
# Out:
# count    8707.000000
# mean       -0.018653
# std         1.028302
# min        -2.491258
# 25%        -0.807391
# 50%         0.034542
# 75%         0.771234
# max         2.665584
# Name: temp, dtype: float64

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['atemp']); 
plt.subplot(122)
data['atemp'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['humidity']); 
plt.subplot(122)
data['humidity'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['windspeed']); 
plt.subplot(122)
data['windspeed'].plot.box(figsize=(16,5)) 
plt.show()

# %%
matrix = data.corr()
f, ax = plt.subplots(figsize=(30, 10))
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %%
import numpy as np

# %%
corrMat = data.corr()
mask = np.array(corrMat)
mask[np.tril_indices_from(mask)] = False
fig, ax= plt.subplots(figsize=(60, 20))
sns.heatmap(corrMat, mask=mask,vmax=1., square=True,annot=True)

# %%
data.corr()
# Out:
#              holiday  workingday      temp  ...   hour_21   hour_22   hour_23
# holiday     1.000000   -0.246736 -0.004834  ... -0.000066 -0.000066 -0.000066
# workingday -0.246736    1.000000  0.031635  ...  0.000759  0.000759  0.000759
# temp       -0.004834    0.031635  1.000000  ...  0.001378 -0.010940 -0.022143
# atemp      -0.014097    0.032455  0.992473  ...  0.003171 -0.008725 -0.019476
# humidity   -0.023067    0.009373 -0.071111  ...  0.001991  0.026105  0.048180
# windspeed   0.013500   -0.001300 -0.022209  ... -0.018752 -0.026133 -0.042005
# casual      0.045411   -0.318682  0.476114  ... -0.025704 -0.051209 -0.082038
# registered -0.024476    0.117624  0.358691  ... -0.010793 -0.057349 -0.112375
# count      -0.006998    0.004650  0.431925  ... -0.016279 -0.061870 -0.115952
# year        0.007004    0.003334  0.053485  ... -0.000837 -0.000837 -0.000837
# day         0.003908   -0.004921  0.028118  ...  0.000469  0.000469  0.000469
# season_1   -0.004153   -0.003844 -0.629844  ...  0.001740  0.001740  0.001740
# season_2   -0.040925    0.013670  0.231149  ... -0.000702 -0.000702 -0.000702
# season_3    0.032666    0.002673  0.607127  ... -0.000731 -0.000731 -0.000731
# season_4    0.020243   -0.015604 -0.187248  ... -0.000481 -0.000481 -0.000481
# weather_1   0.001843   -0.032492  0.058907  ...  0.016455  0.014012  0.004241
# weather_2   0.013390    0.004868 -0.040240  ... -0.014362 -0.009039 -0.011701
# weather_3  -0.024208    0.047856 -0.037125  ... -0.005534 -0.009730  0.011251
# weather_4  -0.001801    0.007297 -0.015900  ... -0.002242 -0.002242 -0.002242
# hour_0     -0.000066   -0.000473 -0.031763  ... -0.043754 -0.043754 -0.043754
# hour_1      0.000030   -0.000864 -0.041114  ... -0.043692 -0.043692 -0.043692
# hour_2      0.000613   -0.000747 -0.045825  ... -0.043315 -0.043315 -0.043315
# hour_3     -0.001597   -0.007649 -0.044119  ... -0.042424 -0.042424 -0.042424
# hour_4      0.001306   -0.004793 -0.056930  ... -0.042871 -0.042871 -0.042871
# hour_5      0.000320    0.002909 -0.070849  ... -0.043504 -0.043504 -0.043504
# hour_6      0.000030    0.000369 -0.073945  ... -0.043692 -0.043692 -0.043692
# hour_7      0.000030    0.000369 -0.065840  ... -0.043692 -0.043692 -0.043692
# hour_8      0.000030    0.000369 -0.049278  ... -0.043692 -0.043692 -0.043692
# hour_9      0.000030    0.000369 -0.025550  ... -0.043692 -0.043692 -0.043692
# hour_10     0.000030    0.000369 -0.000236  ... -0.043692 -0.043692 -0.043692
# hour_11     0.000030    0.000369  0.024902  ... -0.043692 -0.043692 -0.043692
# hour_12    -0.000066    0.000759  0.044079  ... -0.043754 -0.043754 -0.043754
# hour_13    -0.000066    0.000759  0.063318  ... -0.043754 -0.043754 -0.043754
# hour_14    -0.000066    0.000759  0.075636  ... -0.043754 -0.043754 -0.043754
# hour_15    -0.000066    0.000759  0.080563  ... -0.043754 -0.043754 -0.043754
# hour_16    -0.000066    0.000759  0.077865  ... -0.043754 -0.043754 -0.043754
# hour_17    -0.000066    0.000759  0.066310  ... -0.043754 -0.043754 -0.043754
# hour_18    -0.000066    0.000759  0.052760  ... -0.043754 -0.043754 -0.043754
# hour_19    -0.000066    0.000759  0.032465  ... -0.043754 -0.043754 -0.043754
# hour_20    -0.000066    0.000759  0.015866  ... -0.043754 -0.043754 -0.043754
# hour_21    -0.000066    0.000759  0.001378  ...  1.000000 -0.043754 -0.043754
# hour_22    -0.000066    0.000759 -0.010940  ... -0.043754  1.000000 -0.043754
# hour_23    -0.000066    0.000759 -0.022143  ... -0.043754 -0.043754  1.000000
#
# [43 rows x 43 columns]

# %%
data.head()
# Out:
#    holiday  workingday      temp     atemp  ...  hour_20  hour_21  hour_22  hour_23
# 0        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 1        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 2        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 3        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 4        0           0 -1.333599 -1.092687  ...        0        0        0        0
#
# [5 rows x 43 columns]

# %%
def split_valid_test_data(data, fraction=0.2):
    data_y = data["count"]
    
    

    data_x = data.drop(["count","casual","registered"], axis=1)

    

    return data_x.values, data_y

data_x, data_y = split_valid_test_data(data)

# %%
data_x.shape
# Out:
# (8707, 40)

# %%
data.columns
# Out:
# Index(['holiday', 'workingday', 'temp', 'atemp', 'humidity', 'windspeed',
#        'casual', 'registered', 'count', 'year', 'day', 'season_1', 'season_2',
#        'season_3', 'season_4', 'weather_1', 'weather_2', 'weather_3',
#        'weather_4', 'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5',
#        'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23'],
#       dtype='object')

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.optimizers import Adam,SGD,RMSprop,Adagrad

# %%
  
adam = Adam(lr=1e-3, decay=1e-3 / 200)
 
#sgd=SGD(lr=1e-3, decay=1e-3 / 200, momentum=0.9, nesterov=True)
    
#rms=RMSprop(lr=1e-3)
  
#ada=Adagrad(lr=1e-3)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = data_x.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='softplus'))

# Compile the network :
NN_model.compile(loss='mean_squared_logarithmic_error', optimizer=adam, metrics=['mean_absolute_error','mean_squared_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_91 (Dense)             (None, 128)               5248
# _________________________________________________________________
# dense_92 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_93 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_94 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 170,113
# Trainable params: 170,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose =1, save_best_only = True, mode ='auto')
early_stop=EarlyStopping(monitor='val_loss',patience=10)
callbacks_list = [checkpoint,early_stop]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,5])
  plt.legend()
  
 
 
  plt.legend()
  plt.show()

# %%
history=NN_model.fit(data_x, data_y, epochs=100, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Train on 6965 samples, validate on 1742 samples
# Epoch 1/100
# 6965/6965 [==============================] - 2s 291us/step - loss: 2.0185 - mean_absolute_error: 111.5808 - mean_squared_error: 24976.2458 - val_loss: 2.3636 - val_mean_absolute_error: 221.2462 - val_mean_squared_error: 85855.2574
#
# Epoch 00001: val_loss improved from inf to 2.36357, saving model to Weights-001--2.36357.hdf5
# Epoch 2/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 1.9509 - mean_absolute_error: 111.3142 - mean_squared_error: 25054.0253 - val_loss: 2.1929 - val_mean_absolute_error: 216.0015 - val_mean_squared_error: 81824.5098
#
# Epoch 00002: val_loss improved from 2.36357 to 2.19291, saving model to Weights-002--2.19291.hdf5
# Epoch 3/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 1.9330 - mean_absolute_error: 110.5118 - mean_squared_error: 24760.3403 - val_loss: 2.0607 - val_mean_absolute_error: 211.1869 - val_mean_squared_error: 78416.1097
#
# Epoch 00003: val_loss improved from 2.19291 to 2.06065, saving model to Weights-003--2.06065.hdf5
# Epoch 4/100
# 6965/6965 [==============================] - 1s 125us/step - loss: 1.6881 - mean_absolute_error: 103.0463 - mean_squared_error: 22389.7967 - val_loss: 1.3988 - val_mean_absolute_error: 161.5192 - val_mean_squared_error: 49764.8692
#
# Epoch 00004: val_loss improved from 2.06065 to 1.39883, saving model to Weights-004--1.39883.hdf5
# Epoch 5/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 1.3254 - mean_absolute_error: 88.1415 - mean_squared_error: 17064.5614 - val_loss: 1.0841 - val_mean_absolute_error: 147.6284 - val_mean_squared_error: 45106.9754
#
# Epoch 00005: val_loss improved from 1.39883 to 1.08415, saving model to Weights-005--1.08415.hdf5
# Epoch 6/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 1.0975 - mean_absolute_error: 79.4735 - mean_squared_error: 14287.7557 - val_loss: 0.8821 - val_mean_absolute_error: 140.4824 - val_mean_squared_error: 42848.5836
#
# Epoch 00006: val_loss improved from 1.08415 to 0.88210, saving model to Weights-006--0.88210.hdf5
# Epoch 7/100
# 6965/6965 [==============================] - 1s 129us/step - loss: 0.8968 - mean_absolute_error: 74.0696 - mean_squared_error: 12736.0445 - val_loss: 0.7302 - val_mean_absolute_error: 127.7934 - val_mean_squared_error: 36949.2164
#
# Epoch 00007: val_loss improved from 0.88210 to 0.73022, saving model to Weights-007--0.73022.hdf5
# Epoch 8/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.7118 - mean_absolute_error: 69.6036 - mean_squared_error: 11424.6972 - val_loss: 0.5799 - val_mean_absolute_error: 115.9435 - val_mean_squared_error: 31434.8757
#
# Epoch 00008: val_loss improved from 0.73022 to 0.57992, saving model to Weights-008--0.57992.hdf5
# Epoch 9/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 0.6612 - mean_absolute_error: 68.1987 - mean_squared_error: 10838.6429 - val_loss: 0.5550 - val_mean_absolute_error: 118.6287 - val_mean_squared_error: 33107.6601
#
# Epoch 00009: val_loss improved from 0.57992 to 0.55499, saving model to Weights-009--0.55499.hdf5
# Epoch 10/100
# 6965/6965 [==============================] - 1s 133us/step - loss: 0.5777 - mean_absolute_error: 65.9178 - mean_squared_error: 10323.7794 - val_loss: 0.4553 - val_mean_absolute_error: 118.1487 - val_mean_squared_error: 33153.5148
#
# Epoch 00010: val_loss improved from 0.55499 to 0.45528, saving model to Weights-010--0.45528.hdf5
# Epoch 11/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 0.5059 - mean_absolute_error: 63.2941 - mean_squared_error: 9575.2449 - val_loss: 0.4125 - val_mean_absolute_error: 114.2050 - val_mean_squared_error: 31022.1733
#
# Epoch 00011: val_loss improved from 0.45528 to 0.41247, saving model to Weights-011--0.41247.hdf5
# Epoch 12/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 0.5258 - mean_absolute_error: 64.0400 - mean_squared_error: 9665.1894 - val_loss: 0.6644 - val_mean_absolute_error: 143.3533 - val_mean_squared_error: 43232.2916
#
# Epoch 00012: val_loss did not improve from 0.41247
# Epoch 13/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 0.4722 - mean_absolute_error: 60.9250 - mean_squared_error: 8985.2787 - val_loss: 0.4477 - val_mean_absolute_error: 121.7207 - val_mean_squared_error: 33575.2324
#
# Epoch 00013: val_loss did not improve from 0.41247
# Epoch 14/100
# 6965/6965 [==============================] - 1s 129us/step - loss: 0.5000 - mean_absolute_error: 62.0012 - mean_squared_error: 9051.2972 - val_loss: 0.4226 - val_mean_absolute_error: 118.5727 - val_mean_squared_error: 31963.9906
#
# Epoch 00014: val_loss did not improve from 0.41247
# Epoch 15/100
# 6965/6965 [==============================] - 1s 126us/step - loss: 0.4810 - mean_absolute_error: 61.1671 - mean_squared_error: 8845.1499 - val_loss: 0.4051 - val_mean_absolute_error: 110.9819 - val_mean_squared_error: 28708.5897
#
# Epoch 00015: val_loss improved from 0.41247 to 0.40511, saving model to Weights-015--0.40511.hdf5
# Epoch 16/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.4695 - mean_absolute_error: 60.3774 - mean_squared_error: 8711.5441 - val_loss: 0.3873 - val_mean_absolute_error: 113.3083 - val_mean_squared_error: 29388.9981
#
# Epoch 00016: val_loss improved from 0.40511 to 0.38725, saving model to Weights-016--0.38725.hdf5
# Epoch 17/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 0.4614 - mean_absolute_error: 59.9347 - mean_squared_error: 8492.7859 - val_loss: 0.3323 - val_mean_absolute_error: 100.9869 - val_mean_squared_error: 24054.2099
#
# Epoch 00017: val_loss improved from 0.38725 to 0.33234, saving model to Weights-017--0.33234.hdf5
# Epoch 18/100
# 6965/6965 [==============================] - 1s 125us/step - loss: 0.5085 - mean_absolute_error: 62.9367 - mean_squared_error: 9183.7192 - val_loss: 0.4924 - val_mean_absolute_error: 129.7387 - val_mean_squared_error: 36247.8509
#
# Epoch 00018: val_loss did not improve from 0.33234
# Epoch 19/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.4508 - mean_absolute_error: 59.5100 - mean_squared_error: 8383.0758 - val_loss: 0.3420 - val_mean_absolute_error: 105.7040 - val_mean_squared_error: 26114.1348
#
# Epoch 00019: val_loss did not improve from 0.33234
# Epoch 20/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.4732 - mean_absolute_error: 60.8395 - mean_squared_error: 8577.1639 - val_loss: 0.3907 - val_mean_absolute_error: 113.6565 - val_mean_squared_error: 29221.2306
#
# Epoch 00020: val_loss did not improve from 0.33234
# Epoch 21/100
# 6965/6965 [==============================] - 1s 125us/step - loss: 0.4555 - mean_absolute_error: 59.5911 - mean_squared_error: 8367.3820 - val_loss: 0.5849 - val_mean_absolute_error: 133.1401 - val_mean_squared_error: 37070.7767
#
# Epoch 00021: val_loss did not improve from 0.33234
# Epoch 22/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.4409 - mean_absolute_error: 58.7581 - mean_squared_error: 8116.3048 - val_loss: 0.3514 - val_mean_absolute_error: 106.0974 - val_mean_squared_error: 25982.4593
#
# Epoch 00022: val_loss did not improve from 0.33234
# Epoch 23/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 0.4644 - mean_absolute_error: 60.0876 - mean_squared_error: 8485.7255 - val_loss: 0.5788 - val_mean_absolute_error: 133.2970 - val_mean_squared_error: 36961.3878
#
# Epoch 00023: val_loss did not improve from 0.33234
# Epoch 24/100
# 6965/6965 [==============================] - 1s 127us/step - loss: 0.4669 - mean_absolute_error: 59.9858 - mean_squared_error: 8496.5766 - val_loss: 0.4458 - val_mean_absolute_error: 122.5813 - val_mean_squared_error: 32467.6188
#
# Epoch 00024: val_loss did not improve from 0.33234
# Epoch 25/100
# 6965/6965 [==============================] - 1s 128us/step - loss: 0.4499 - mean_absolute_error: 59.0404 - mean_squared_error: 8146.1264 - val_loss: 0.4807 - val_mean_absolute_error: 120.4233 - val_mean_squared_error: 31330.9264
#
# Epoch 00025: val_loss did not improve from 0.33234
# Epoch 26/100
# 6965/6965 [==============================] - 1s 129us/step - loss: 0.4464 - mean_absolute_error: 59.1084 - mean_squared_error: 8228.9992 - val_loss: 0.3542 - val_mean_absolute_error: 92.8856 - val_mean_squared_error: 19411.3483
#
# Epoch 00026: val_loss did not improve from 0.33234
# Epoch 27/100
# 6965/6965 [==============================] - 1s 129us/step - loss: 0.4405 - mean_absolute_error: 58.8757 - mean_squared_error: 8076.9263 - val_loss: 0.6949 - val_mean_absolute_error: 143.4014 - val_mean_squared_error: 40779.7800
#
# Epoch 00027: val_loss did not improve from 0.33234

# %%
data['count'].describe()
# Out:
# count    8707.000000
# mean      174.409670
# std       166.438566
# min         1.000000
# 25%        38.000000
# 50%       130.000000
# 75%       259.000000
# max       891.000000
# Name: count, dtype: float64

# %%
test=pd.read_csv("test.csv")
test_original=test.copy()

# %%
test.shape
# Out:
# (6493, 9)

# %%
test.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed'],
#       dtype='object')

# %%
test['datetime'] = pd.to_datetime(test['datetime'], errors='coerce')

# %%
test['year'] = test['datetime'].dt.year 
#test['month'] = test['datetime'].dt.month 
test['day'] = test['datetime'].dt.day 
test['hour'] = test['datetime'].dt.hour

# %%
test=test.drop('datetime',axis=1)

# %%
test=normalize(test,["temp","atemp","humidity","windspeed"])

# %%
test = dummy_data(test, ["season","weather","hour"])

# %%
test.shape
# Out:
# (6493, 40)

# %%
test.columns
# Out:
# Index(['holiday', 'workingday', 'temp', 'atemp', 'humidity', 'windspeed',
#        'year', 'day', 'season_1', 'season_2', 'season_3', 'season_4',
#        'weather_1', 'weather_2', 'weather_3', 'weather_4', 'hour_0', 'hour_1',
#        'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7', 'hour_8',
#        'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13', 'hour_14',
#        'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19', 'hour_20',
#        'hour_21', 'hour_22', 'hour_23'],
#       dtype='object')

# %%
test1_x, test1_y = split_valid_test_data(test1)

# %%
preds=NN_model.predict(test1_x)

# %%
#making predictions
prediction=NN_model.predict(test)

# %%
import logging
logger=logging.getLogger()

# %%
preds=NN_model.predict(test1_x)

# %%
from keras import metrics

# %%
mse=metrics.mean_squared_error(test1_y,preds)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-422-68e6a8def41f> in <module>()
# ----> 1 mse=metrics.mean_squared_error(test1_y,preds)
#
# /usr/local/lib/python3.6/dist-packages/keras/losses.py in mean_squared_error(y_true, y_pred)
#      12
#      13 def mean_squared_error(y_true, y_pred):
# ---> 14     return K.mean(K.square(y_pred - y_true), axis=-1)
#      15
#      16
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in wrapper(left, right)
#    1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
# -> 1585                                 index=left.index, name=res_name, dtype=None)
#    1586
#    1587     wrapper.__name__ = op_name
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in _construct_result(left, result, index, name, dtype)
#    1472     not be enough; we still need to override the name attribute.
#    1473     """
# -> 1474     out = left._constructor(result, index=index, dtype=dtype)
#    1475
#    1476     out.name = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     656     elif subarr.ndim > 1:
#     657         if isinstance(data, np.ndarray):
# --> 658             raise Exception('Data must be 1-dimensional')
#     659         else:
#     660             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
#prediction=pd.DataFrame(prediction)

#prediction=prediction.clip(lower=0)
#prediction

# %%
import keras.backend as K

def mean_pred(y_true, y_pred):
    return K.mean(y_pred)

# %%
evaluation=test_original['datetime'].to_frame()
evaluation["count"]=prediction
evaluation[:10]
# Out:
#               datetime       count
# 0  2011-01-20 00:00:00   12.484183
# 1  2011-01-20 01:00:00    5.482817
# 2  2011-01-20 02:00:00    3.354281
# 3  2011-01-20 03:00:00    2.179120
# 4  2011-01-20 04:00:00    2.121344
# 5  2011-01-20 05:00:00   10.160122
# 6  2011-01-20 06:00:00   55.021420
# 7  2011-01-20 07:00:00  150.138443
# 8  2011-01-20 08:00:00  280.271149
# 9  2011-01-20 09:00:00  132.132675

# %%
evaluation["count"] = evaluation["count"].astype(int)
evaluation["count"]
# Out:
# 0        14
# 1         7
# 2         4
# 3         2
# 4         2
# 5        13
# 6        47
# 7       152
# 8       262
# 9       136
# 10       69
# 11       74
# 12      107
# 13       86
# 14       79
# 15       84
# 16      119
# 17      259
# 18      203
# 19      141
# 20       91
# 21       68
# 22       49
# 23       32
# 24       12
# 25        5
# 26        3
# 27        2
# 28        2
# 29       12
#        ...
# 6463     99
# 6464    115
# 6465     59
# 6466     51
# 6467     38
# 6468     29
# 6469     13
# 6470      6
# 6471      3
# 6472      2
# 6473      2
# 6474     12
# 6475     45
# 6476    133
# 6477    223
# 6478    131
# 6479     61
# 6480     66
# 6481     80
# 6482     86
# 6483     78
# 6484     85
# 6485    110
# 6486    244
# 6487    222
# 6488    145
# 6489    103
# 6490     90
# 6491     73
# 6492     42
# Name: count, Length: 6493, dtype: int64

# %%
evaluation.to_csv("submissionv19.csv",index=False)
