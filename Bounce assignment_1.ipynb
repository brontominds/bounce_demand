# %%
import pandas as pd

# %%
data=pd.read_csv("train.csv")#Making it Relative Path -Mayank

# %%
data.head()
# Out:
#               datetime  season  holiday  ...  casual  registered  count
# 0  2011-01-01 00:00:00       1        0  ...       3          13     16
# 1  2011-01-01 01:00:00       1        0  ...       8          32     40
# 2  2011-01-01 02:00:00       1        0  ...       5          27     32
# 3  2011-01-01 03:00:00       1        0  ...       3          10     13
# 4  2011-01-01 04:00:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
import matplotlib.pyplot as plt  # For plotting graphs 
from datetime import datetime    # To access datetime 
from pandas import Series        # To work on series 
# %matplotlib inline

# %%
data.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
data.shape
# Out:
# (10886, 12)

# %%
data['datetime'] = pd.to_datetime(data['datetime'], errors='coerce')

# %%
data['year'] = data['datetime'].dt.year 
#data['month'] = data['datetime'].dt.month 
data['day'] = data['datetime'].dt.day 
data['hour'] = data['datetime'].dt.hour

# %%
data.head()
# Out:
#              datetime  season  holiday  workingday  ...  count  year  day  hour
# 0 2011-01-01 00:00:00       1        0           0  ...     16  2011    1     0
# 1 2011-01-01 01:00:00       1        0           0  ...     40  2011    1     1
# 2 2011-01-01 02:00:00       1        0           0  ...     32  2011    1     2
# 3 2011-01-01 03:00:00       1        0           0  ...     13  2011    1     3
# 4 2011-01-01 04:00:00       1        0           0  ...      1  2011    1     4
#
# [5 rows x 15 columns]

# %%
data=data.drop('datetime',axis=1)

# %%
def normalize(df,columns):
    result=df.copy()
    for feature_name in columns :
        mean_value = df[feature_name].mean()
        std_value = df[feature_name].std()
        result[feature_name] = (df[feature_name] - mean_value) / std_value
        
    return result

# %%
data=normalize(data,["temp","atemp","humidity","windspeed"])

# %%
def dummy_data(data, columns):
    for column in columns:
        data = pd.concat([data, pd.get_dummies(data[column], prefix=column)], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
data = dummy_data(data, ["season","weather","hour"])

# %%
data.head()
# Out:
#    holiday  workingday      temp     atemp  ...  hour_20  hour_21  hour_22  hour_23
# 0        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 1        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 2        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 3        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 4        0           0 -1.333599 -1.092687  ...        0        0        0        0
#
# [5 rows x 43 columns]

# %%
import seaborn as sns

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['temp']); 
plt.subplot(122)
data_normalize['temp'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.scatter(data['temp'],data['count'],alpha=0.1,
            cmap='viridis')

# %%
data['temp'].describe()
# Out:
# count    1.088600e+04
# mean     1.118943e-14
# std      1.000000e+00
# min     -2.491258e+00
# 25%     -8.073910e-01
# 50%      3.454240e-02
# 75%      7.712342e-01
# max      2.665584e+00
# Name: temp, dtype: float64

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['atemp']); 
plt.subplot(122)
data_normalize['atemp'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['humidity']); 
plt.subplot(122)
data_normalize['humidity'].plot.box(figsize=(16,5)) 
plt.show()

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(data['windspeed']); 
plt.subplot(122)
data_normalize['windspeed'].plot.box(figsize=(16,5)) 
plt.show()

# %%
matrix = data.corr()
f, ax = plt.subplots(figsize=(30, 10))
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %%
import numpy as np

# %%
corrMat = data.corr()
mask = np.array(corrMat)
mask[np.tril_indices_from(mask)] = False
fig, ax= plt.subplots(figsize=(60, 20))
sns.heatmap(corrMat, mask=mask,vmax=1., square=True,annot=True)

# %%
data.corr()
# Out:
#              holiday  workingday      temp  ...   hour_21   hour_22   hour_23
# holiday     1.000000   -0.250491  0.000295  ... -0.000075 -0.000075 -0.000075
# workingday -0.250491    1.000000  0.029966  ...  0.000513  0.000513  0.000513
# temp        0.000295    0.029966  1.000000  ... -0.000354 -0.012467 -0.023808
# atemp      -0.005215    0.024660  0.984948  ...  0.001621 -0.010430 -0.021702
# humidity    0.001929   -0.010880 -0.064949  ...  0.005666  0.029136  0.051748
# windspeed   0.008409    0.013373 -0.017852  ... -0.019514 -0.024450 -0.044105
# casual      0.043799   -0.319111  0.467097  ... -0.031198 -0.056163 -0.086048
# registered -0.020956    0.119460  0.318571  ... -0.014882 -0.061716 -0.112840
# count      -0.005393    0.011594  0.394454  ... -0.021013 -0.066949 -0.117819
# year        0.012021   -0.002482  0.061226  ... -0.000807 -0.000807 -0.000807
# day        -0.015877    0.009829  0.015551  ...  0.000284  0.000284  0.000284
# season_1   -0.007336   -0.000379 -0.565655  ...  0.001582  0.001582  0.001582
# season_2   -0.038250    0.014620  0.192661  ... -0.000509 -0.000509 -0.000509
# season_3    0.022790   -0.007194  0.635975  ... -0.000509 -0.000509 -0.000509
# season_4    0.022751   -0.007048 -0.266220  ... -0.000554 -0.000554 -0.000554
# weather_1  -0.001708   -0.024078  0.058430  ...  0.014272  0.016208  0.008461
# weather_2   0.013868    0.003324 -0.046925  ... -0.011194 -0.014329 -0.016419
# weather_3  -0.019514    0.036643 -0.025715  ... -0.006773 -0.005073  0.011936
# weather_4  -0.001644    0.006562 -0.014800  ... -0.002004 -0.002004 -0.002004
# hour_0      0.000003    0.000199 -0.032641  ... -0.043670 -0.043670 -0.043670
# hour_1      0.000082   -0.000115 -0.042606  ... -0.043620 -0.043620 -0.043620
# hour_2      0.000558   -0.000032 -0.047208  ... -0.043318 -0.043318 -0.043318
# hour_3     -0.001045   -0.005867 -0.046941  ... -0.042556 -0.042556 -0.042556
# hour_4      0.001041   -0.003941 -0.057946  ... -0.043015 -0.043015 -0.043015
# hour_5      0.000240    0.002217 -0.070012  ... -0.043520 -0.043520 -0.043520
# hour_6      0.000003    0.000199 -0.073705  ... -0.043670 -0.043670 -0.043670
# hour_7      0.000003    0.000199 -0.065492  ... -0.043670 -0.043670 -0.043670
# hour_8      0.000003    0.000199 -0.047424  ... -0.043670 -0.043670 -0.043670
# hour_9      0.000003    0.000199 -0.023366  ... -0.043670 -0.043670 -0.043670
# hour_10     0.000003    0.000199  0.002384  ... -0.043670 -0.043670 -0.043670
# hour_11     0.000003    0.000199  0.027650  ... -0.043670 -0.043670 -0.043670
# hour_12    -0.000075    0.000513  0.047520  ... -0.043720 -0.043720 -0.043720
# hour_13    -0.000075    0.000513  0.066003  ... -0.043720 -0.043720 -0.043720
# hour_14    -0.000075    0.000513  0.078261  ... -0.043720 -0.043720 -0.043720
# hour_15    -0.000075    0.000513  0.081880  ... -0.043720 -0.043720 -0.043720
# hour_16    -0.000075    0.000513  0.077489  ... -0.043720 -0.043720 -0.043720
# hour_17    -0.000075    0.000513  0.065038  ... -0.043720 -0.043720 -0.043720
# hour_18    -0.000075    0.000513  0.050367  ... -0.043720 -0.043720 -0.043720
# hour_19    -0.000075    0.000513  0.030436  ... -0.043720 -0.043720 -0.043720
# hour_20    -0.000075    0.000513  0.013931  ... -0.043720 -0.043720 -0.043720
# hour_21    -0.000075    0.000513 -0.000354  ...  1.000000 -0.043720 -0.043720
# hour_22    -0.000075    0.000513 -0.012467  ... -0.043720  1.000000 -0.043720
# hour_23    -0.000075    0.000513 -0.023808  ... -0.043720 -0.043720  1.000000
#
# [43 rows x 43 columns]

# %%
data.head()
# Out:
#    holiday  workingday      temp     atemp  ...  hour_20  hour_21  hour_22  hour_23
# 0        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 1        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 2        0           0 -1.438841 -1.182367  ...        0        0        0        0
# 3        0           0 -1.333599 -1.092687  ...        0        0        0        0
# 4        0           0 -1.333599 -1.092687  ...        0        0        0        0
#
# [5 rows x 43 columns]

# %%
def split_valid_test_data(data, fraction=0.2):
    data_y = data["count"]
    
    

    data_x = data.drop(["count","casual","registered"], axis=1)

    

    return data_x.values, data_y

data_x, data_y = split_valid_test_data(data)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

# %%
opt = Adam(lr=1e-3, decay=1e-3 / 200)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = data_x.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='softplus'))

# Compile the network :
NN_model.compile(loss='mean_squared_logarithmic_error', optimizer=opt, metrics=['mean_absolute_error','mean_squared_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 128)               5248
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 170,113
# Trainable params: 170,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose =1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,5])
  plt.legend()
  
 
 
  plt.legend()
  plt.show()

# %%
history=NN_model.fit(data_x, data_y, epochs=100, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Train on 8708 samples, validate on 2178 samples
# Epoch 1/100
# 8708/8708 [==============================] - 2s 248us/step - loss: 2.1215 - mean_absolute_error: 130.6316 - mean_squared_error: 34898.5098 - val_loss: 2.2029 - val_mean_absolute_error: 208.9981 - val_mean_squared_error: 80486.0720
#
# Epoch 00001: val_loss improved from inf to 2.20288, saving model to Weights-001--2.20288.hdf5
# Epoch 2/100
# 8708/8708 [==============================] - 1s 123us/step - loss: 1.9751 - mean_absolute_error: 128.8867 - mean_squared_error: 34433.1816 - val_loss: 1.7663 - val_mean_absolute_error: 191.4934 - val_mean_squared_error: 68596.8683
#
# Epoch 00002: val_loss improved from 2.20288 to 1.76635, saving model to Weights-002--1.76635.hdf5
# Epoch 3/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 1.5458 - mean_absolute_error: 111.1801 - mean_squared_error: 27146.8289 - val_loss: 1.3930 - val_mean_absolute_error: 169.9423 - val_mean_squared_error: 58118.3943
#
# Epoch 00003: val_loss improved from 1.76635 to 1.39303, saving model to Weights-003--1.39303.hdf5
# Epoch 4/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 1.1157 - mean_absolute_error: 91.8876 - mean_squared_error: 19349.7848 - val_loss: 1.1259 - val_mean_absolute_error: 154.6571 - val_mean_squared_error: 50719.4789
#
# Epoch 00004: val_loss improved from 1.39303 to 1.12590, saving model to Weights-004--1.12590.hdf5
# Epoch 5/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.8154 - mean_absolute_error: 83.2263 - mean_squared_error: 16496.1962 - val_loss: 0.5561 - val_mean_absolute_error: 115.6060 - val_mean_squared_error: 32884.3288
#
# Epoch 00005: val_loss improved from 1.12590 to 0.55611, saving model to Weights-005--0.55611.hdf5
# Epoch 6/100
# 8708/8708 [==============================] - 1s 136us/step - loss: 0.6300 - mean_absolute_error: 77.6198 - mean_squared_error: 14557.2726 - val_loss: 0.4462 - val_mean_absolute_error: 104.0137 - val_mean_squared_error: 26728.7307
#
# Epoch 00006: val_loss improved from 0.55611 to 0.44622, saving model to Weights-006--0.44622.hdf5
# Epoch 7/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.5377 - mean_absolute_error: 73.8208 - mean_squared_error: 13329.1448 - val_loss: 0.9491 - val_mean_absolute_error: 152.9360 - val_mean_squared_error: 48354.6114
#
# Epoch 00007: val_loss did not improve from 0.44622
# Epoch 8/100
# 8708/8708 [==============================] - 1s 138us/step - loss: 0.5122 - mean_absolute_error: 72.9058 - mean_squared_error: 12906.7111 - val_loss: 0.3949 - val_mean_absolute_error: 100.7711 - val_mean_squared_error: 25023.9111
#
# Epoch 00008: val_loss improved from 0.44622 to 0.39489, saving model to Weights-008--0.39489.hdf5
# Epoch 9/100
# 8708/8708 [==============================] - 1s 139us/step - loss: 0.4868 - mean_absolute_error: 71.3304 - mean_squared_error: 12381.5460 - val_loss: 0.4259 - val_mean_absolute_error: 108.7134 - val_mean_squared_error: 28450.5559
#
# Epoch 00009: val_loss did not improve from 0.39489
# Epoch 10/100
# 8708/8708 [==============================] - 1s 136us/step - loss: 0.4716 - mean_absolute_error: 70.2620 - mean_squared_error: 11984.8326 - val_loss: 0.4554 - val_mean_absolute_error: 94.2908 - val_mean_squared_error: 19977.1847
#
# Epoch 00010: val_loss did not improve from 0.39489
# Epoch 11/100
# 8708/8708 [==============================] - 1s 139us/step - loss: 0.4977 - mean_absolute_error: 72.2179 - mean_squared_error: 12558.1146 - val_loss: 0.4163 - val_mean_absolute_error: 93.8516 - val_mean_squared_error: 19860.0660
#
# Epoch 00011: val_loss did not improve from 0.39489
# Epoch 12/100
# 8708/8708 [==============================] - 1s 139us/step - loss: 0.4852 - mean_absolute_error: 71.2294 - mean_squared_error: 12175.0258 - val_loss: 0.3780 - val_mean_absolute_error: 98.1446 - val_mean_squared_error: 23033.4609
#
# Epoch 00012: val_loss improved from 0.39489 to 0.37797, saving model to Weights-012--0.37797.hdf5
# Epoch 13/100
# 8708/8708 [==============================] - 1s 139us/step - loss: 0.4523 - mean_absolute_error: 68.0864 - mean_squared_error: 11176.3598 - val_loss: 0.4024 - val_mean_absolute_error: 91.8148 - val_mean_squared_error: 17952.9533
#
# Epoch 00013: val_loss did not improve from 0.37797
# Epoch 14/100
# 8708/8708 [==============================] - 1s 135us/step - loss: 0.4403 - mean_absolute_error: 67.2406 - mean_squared_error: 10935.2076 - val_loss: 0.3799 - val_mean_absolute_error: 101.4504 - val_mean_squared_error: 24303.4878
#
# Epoch 00014: val_loss did not improve from 0.37797
# Epoch 15/100
# 8708/8708 [==============================] - 1s 136us/step - loss: 0.4330 - mean_absolute_error: 67.3318 - mean_squared_error: 10924.4320 - val_loss: 0.3506 - val_mean_absolute_error: 94.0241 - val_mean_squared_error: 20744.3766
#
# Epoch 00015: val_loss improved from 0.37797 to 0.35063, saving model to Weights-015--0.35063.hdf5
# Epoch 16/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4400 - mean_absolute_error: 67.9148 - mean_squared_error: 11061.3197 - val_loss: 0.6630 - val_mean_absolute_error: 132.5553 - val_mean_squared_error: 36318.8119
#
# Epoch 00016: val_loss did not improve from 0.35063
# Epoch 17/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4497 - mean_absolute_error: 68.8403 - mean_squared_error: 11369.3832 - val_loss: 1.5839 - val_mean_absolute_error: 179.5676 - val_mean_squared_error: 59008.0709
#
# Epoch 00017: val_loss did not improve from 0.35063
# Epoch 18/100
# 8708/8708 [==============================] - 1s 130us/step - loss: 0.4644 - mean_absolute_error: 69.3431 - mean_squared_error: 11632.0273 - val_loss: 0.7618 - val_mean_absolute_error: 140.4755 - val_mean_squared_error: 40153.0995
#
# Epoch 00018: val_loss did not improve from 0.35063
# Epoch 19/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.4391 - mean_absolute_error: 68.2652 - mean_squared_error: 11115.6808 - val_loss: 0.5225 - val_mean_absolute_error: 121.9151 - val_mean_squared_error: 32475.6337
#
# Epoch 00019: val_loss did not improve from 0.35063
# Epoch 20/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4236 - mean_absolute_error: 66.6489 - mean_squared_error: 10793.9727 - val_loss: 0.3480 - val_mean_absolute_error: 93.6005 - val_mean_squared_error: 20244.4947
#
# Epoch 00020: val_loss improved from 0.35063 to 0.34800, saving model to Weights-020--0.34800.hdf5
# Epoch 21/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4452 - mean_absolute_error: 68.0401 - mean_squared_error: 11115.2480 - val_loss: 0.6227 - val_mean_absolute_error: 136.7745 - val_mean_squared_error: 38833.3095
#
# Epoch 00021: val_loss did not improve from 0.34800
# Epoch 22/100
# 8708/8708 [==============================] - 1s 123us/step - loss: 0.4461 - mean_absolute_error: 68.5914 - mean_squared_error: 11318.5823 - val_loss: 0.4665 - val_mean_absolute_error: 112.9100 - val_mean_squared_error: 28784.3368
#
# Epoch 00022: val_loss did not improve from 0.34800
# Epoch 23/100
# 8708/8708 [==============================] - 1s 124us/step - loss: 0.4488 - mean_absolute_error: 68.8318 - mean_squared_error: 11393.8086 - val_loss: 0.4526 - val_mean_absolute_error: 113.7110 - val_mean_squared_error: 29322.3107
#
# Epoch 00023: val_loss did not improve from 0.34800
# Epoch 24/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4473 - mean_absolute_error: 68.1786 - mean_squared_error: 11219.1074 - val_loss: 0.3755 - val_mean_absolute_error: 100.6035 - val_mean_squared_error: 23617.9820
#
# Epoch 00024: val_loss did not improve from 0.34800
# Epoch 25/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.4299 - mean_absolute_error: 66.9477 - mean_squared_error: 10854.2350 - val_loss: 0.7142 - val_mean_absolute_error: 132.9152 - val_mean_squared_error: 36297.5169
#
# Epoch 00025: val_loss did not improve from 0.34800
# Epoch 26/100
# 8708/8708 [==============================] - 1s 130us/step - loss: 0.4311 - mean_absolute_error: 67.7175 - mean_squared_error: 10970.7076 - val_loss: 0.4269 - val_mean_absolute_error: 110.1522 - val_mean_squared_error: 27623.9578
#
# Epoch 00026: val_loss did not improve from 0.34800
# Epoch 27/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4181 - mean_absolute_error: 65.9925 - mean_squared_error: 10508.2230 - val_loss: 0.5899 - val_mean_absolute_error: 119.7579 - val_mean_squared_error: 30724.9291
#
# Epoch 00027: val_loss did not improve from 0.34800
# Epoch 28/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4497 - mean_absolute_error: 68.6167 - mean_squared_error: 11265.4365 - val_loss: 0.4507 - val_mean_absolute_error: 109.0550 - val_mean_squared_error: 26701.1739
#
# Epoch 00028: val_loss did not improve from 0.34800
# Epoch 29/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.4288 - mean_absolute_error: 66.9788 - mean_squared_error: 10743.9167 - val_loss: 0.3556 - val_mean_absolute_error: 95.8782 - val_mean_squared_error: 21221.2599
#
# Epoch 00029: val_loss did not improve from 0.34800
# Epoch 30/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.4495 - mean_absolute_error: 67.7726 - mean_squared_error: 11051.5144 - val_loss: 0.6443 - val_mean_absolute_error: 130.6317 - val_mean_squared_error: 35674.2840
#
# Epoch 00030: val_loss did not improve from 0.34800
# Epoch 31/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4333 - mean_absolute_error: 67.2740 - mean_squared_error: 10883.7042 - val_loss: 0.4317 - val_mean_absolute_error: 106.2475 - val_mean_squared_error: 25633.2790
#
# Epoch 00031: val_loss did not improve from 0.34800
# Epoch 32/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4354 - mean_absolute_error: 67.4568 - mean_squared_error: 10808.9527 - val_loss: 0.8846 - val_mean_absolute_error: 157.1024 - val_mean_squared_error: 48645.6633
#
# Epoch 00032: val_loss did not improve from 0.34800
# Epoch 33/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4378 - mean_absolute_error: 67.8656 - mean_squared_error: 11058.4615 - val_loss: 0.7054 - val_mean_absolute_error: 139.3066 - val_mean_squared_error: 39397.3047
#
# Epoch 00033: val_loss did not improve from 0.34800
# Epoch 34/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4212 - mean_absolute_error: 66.6712 - mean_squared_error: 10713.0707 - val_loss: 0.6677 - val_mean_absolute_error: 132.8466 - val_mean_squared_error: 36371.8764
#
# Epoch 00034: val_loss did not improve from 0.34800
# Epoch 35/100
# 8708/8708 [==============================] - 1s 134us/step - loss: 0.4301 - mean_absolute_error: 66.8326 - mean_squared_error: 10608.5105 - val_loss: 0.6741 - val_mean_absolute_error: 131.7319 - val_mean_squared_error: 36190.9420
#
# Epoch 00035: val_loss did not improve from 0.34800
# Epoch 36/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4288 - mean_absolute_error: 66.9295 - mean_squared_error: 10863.7110 - val_loss: 0.4160 - val_mean_absolute_error: 111.9624 - val_mean_squared_error: 28655.1279
#
# Epoch 00036: val_loss did not improve from 0.34800
# Epoch 37/100
# 8708/8708 [==============================] - 1s 124us/step - loss: 0.4273 - mean_absolute_error: 66.6186 - mean_squared_error: 10715.9113 - val_loss: 0.5175 - val_mean_absolute_error: 125.8868 - val_mean_squared_error: 34164.0707
#
# Epoch 00037: val_loss did not improve from 0.34800
# Epoch 38/100
# 8708/8708 [==============================] - 1s 130us/step - loss: 0.4260 - mean_absolute_error: 66.8085 - mean_squared_error: 10659.4784 - val_loss: 0.5909 - val_mean_absolute_error: 121.2467 - val_mean_squared_error: 31582.7420
#
# Epoch 00038: val_loss did not improve from 0.34800
# Epoch 39/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4083 - mean_absolute_error: 65.8944 - mean_squared_error: 10488.8494 - val_loss: 0.4365 - val_mean_absolute_error: 111.0578 - val_mean_squared_error: 26987.7605
#
# Epoch 00039: val_loss did not improve from 0.34800
# Epoch 40/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 0.4187 - mean_absolute_error: 66.5255 - mean_squared_error: 10602.7638 - val_loss: 0.3956 - val_mean_absolute_error: 102.2737 - val_mean_squared_error: 23747.2073
#
# Epoch 00040: val_loss did not improve from 0.34800
# Epoch 41/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.4059 - mean_absolute_error: 65.2970 - mean_squared_error: 10222.0717 - val_loss: 0.5071 - val_mean_absolute_error: 115.7028 - val_mean_squared_error: 29281.6678
#
# Epoch 00041: val_loss did not improve from 0.34800
# Epoch 42/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4191 - mean_absolute_error: 66.2857 - mean_squared_error: 10501.2778 - val_loss: 1.0280 - val_mean_absolute_error: 157.9575 - val_mean_squared_error: 47654.9072
#
# Epoch 00042: val_loss did not improve from 0.34800
# Epoch 43/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4237 - mean_absolute_error: 66.6938 - mean_squared_error: 10547.0631 - val_loss: 0.4627 - val_mean_absolute_error: 115.7658 - val_mean_squared_error: 29759.0022
#
# Epoch 00043: val_loss did not improve from 0.34800
# Epoch 44/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4117 - mean_absolute_error: 65.7582 - mean_squared_error: 10426.2483 - val_loss: 0.4076 - val_mean_absolute_error: 106.1383 - val_mean_squared_error: 25894.0363
#
# Epoch 00044: val_loss did not improve from 0.34800
# Epoch 45/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4165 - mean_absolute_error: 66.1251 - mean_squared_error: 10392.0893 - val_loss: 0.9079 - val_mean_absolute_error: 152.3434 - val_mean_squared_error: 45223.9476
#
# Epoch 00045: val_loss did not improve from 0.34800
# Epoch 46/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.4085 - mean_absolute_error: 65.2682 - mean_squared_error: 10273.6032 - val_loss: 0.3658 - val_mean_absolute_error: 98.1604 - val_mean_squared_error: 22245.3798
#
# Epoch 00046: val_loss did not improve from 0.34800
# Epoch 47/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4294 - mean_absolute_error: 66.9821 - mean_squared_error: 10551.6857 - val_loss: 0.6825 - val_mean_absolute_error: 140.4868 - val_mean_squared_error: 40505.9647
#
# Epoch 00047: val_loss did not improve from 0.34800
# Epoch 48/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.4074 - mean_absolute_error: 65.5534 - mean_squared_error: 10339.0524 - val_loss: 0.5398 - val_mean_absolute_error: 128.5423 - val_mean_squared_error: 34995.3100
#
# Epoch 00048: val_loss did not improve from 0.34800
# Epoch 49/100
# 8708/8708 [==============================] - 1s 124us/step - loss: 0.3983 - mean_absolute_error: 64.6957 - mean_squared_error: 10053.6608 - val_loss: 0.4672 - val_mean_absolute_error: 114.1425 - val_mean_squared_error: 28640.8129
#
# Epoch 00049: val_loss did not improve from 0.34800
# Epoch 50/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4089 - mean_absolute_error: 65.4287 - mean_squared_error: 10322.4279 - val_loss: 0.3520 - val_mean_absolute_error: 97.0571 - val_mean_squared_error: 21892.6008
#
# Epoch 00050: val_loss did not improve from 0.34800
# Epoch 51/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.4053 - mean_absolute_error: 64.7014 - mean_squared_error: 10051.0418 - val_loss: 0.9825 - val_mean_absolute_error: 153.4054 - val_mean_squared_error: 45544.3086
#
# Epoch 00051: val_loss did not improve from 0.34800
# Epoch 52/100
# 8708/8708 [==============================] - 1s 130us/step - loss: 0.4089 - mean_absolute_error: 65.4288 - mean_squared_error: 10308.4037 - val_loss: 0.3794 - val_mean_absolute_error: 99.5137 - val_mean_squared_error: 22966.9219
#
# Epoch 00052: val_loss did not improve from 0.34800
# Epoch 53/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.3950 - mean_absolute_error: 64.1175 - mean_squared_error: 9856.9737 - val_loss: 0.5888 - val_mean_absolute_error: 129.3586 - val_mean_squared_error: 34704.6348
#
# Epoch 00053: val_loss did not improve from 0.34800
# Epoch 54/100
# 8708/8708 [==============================] - 1s 130us/step - loss: 0.4060 - mean_absolute_error: 65.7554 - mean_squared_error: 10315.6223 - val_loss: 0.4734 - val_mean_absolute_error: 116.5115 - val_mean_squared_error: 29984.6118
#
# Epoch 00054: val_loss did not improve from 0.34800
# Epoch 55/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.3887 - mean_absolute_error: 63.9482 - mean_squared_error: 9870.5609 - val_loss: 0.3664 - val_mean_absolute_error: 100.5824 - val_mean_squared_error: 23313.0839
#
# Epoch 00055: val_loss did not improve from 0.34800
# Epoch 56/100
# 8708/8708 [==============================] - 1s 141us/step - loss: 0.3836 - mean_absolute_error: 63.7038 - mean_squared_error: 9718.0219 - val_loss: 0.4226 - val_mean_absolute_error: 108.6325 - val_mean_squared_error: 26098.3258
#
# Epoch 00056: val_loss did not improve from 0.34800
# Epoch 57/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.3852 - mean_absolute_error: 63.6758 - mean_squared_error: 9723.0279 - val_loss: 0.3554 - val_mean_absolute_error: 98.3444 - val_mean_squared_error: 22275.3166
#
# Epoch 00057: val_loss did not improve from 0.34800
# Epoch 58/100
# 8708/8708 [==============================] - 1s 123us/step - loss: 0.3830 - mean_absolute_error: 62.7254 - mean_squared_error: 9584.0472 - val_loss: 0.7280 - val_mean_absolute_error: 139.0025 - val_mean_squared_error: 38910.0770
#
# Epoch 00058: val_loss did not improve from 0.34800
# Epoch 59/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.3782 - mean_absolute_error: 62.5496 - mean_squared_error: 9481.9510 - val_loss: 0.5270 - val_mean_absolute_error: 115.1202 - val_mean_squared_error: 28521.7183
#
# Epoch 00059: val_loss did not improve from 0.34800
# Epoch 60/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.3544 - mean_absolute_error: 61.0566 - mean_squared_error: 9017.1948 - val_loss: 0.4738 - val_mean_absolute_error: 115.2354 - val_mean_squared_error: 28703.5431
#
# Epoch 00060: val_loss did not improve from 0.34800
# Epoch 61/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 0.3691 - mean_absolute_error: 61.3899 - mean_squared_error: 9124.3291 - val_loss: 0.2988 - val_mean_absolute_error: 87.2165 - val_mean_squared_error: 17660.6952
#
# Epoch 00061: val_loss improved from 0.34800 to 0.29879, saving model to Weights-061--0.29879.hdf5
# Epoch 62/100
# 8708/8708 [==============================] - 1s 134us/step - loss: 0.3569 - mean_absolute_error: 61.0386 - mean_squared_error: 8999.8704 - val_loss: 0.2827 - val_mean_absolute_error: 77.3876 - val_mean_squared_error: 13587.2592
#
# Epoch 00062: val_loss improved from 0.29879 to 0.28273, saving model to Weights-062--0.28273.hdf5
# Epoch 63/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.4144 - mean_absolute_error: 64.6166 - mean_squared_error: 9875.1004 - val_loss: 0.3431 - val_mean_absolute_error: 91.5309 - val_mean_squared_error: 18993.0209
#
# Epoch 00063: val_loss did not improve from 0.28273
# Epoch 64/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.4026 - mean_absolute_error: 63.1931 - mean_squared_error: 9602.4318 - val_loss: 0.7004 - val_mean_absolute_error: 135.3611 - val_mean_squared_error: 37279.3353
#
# Epoch 00064: val_loss did not improve from 0.28273
# Epoch 65/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.3933 - mean_absolute_error: 63.5541 - mean_squared_error: 9603.2631 - val_loss: 0.8081 - val_mean_absolute_error: 151.1674 - val_mean_squared_error: 44717.7107
#
# Epoch 00065: val_loss did not improve from 0.28273
# Epoch 66/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 0.3696 - mean_absolute_error: 61.6521 - mean_squared_error: 9192.3414 - val_loss: 0.6214 - val_mean_absolute_error: 128.7765 - val_mean_squared_error: 32293.7870
#
# Epoch 00066: val_loss did not improve from 0.28273
# Epoch 67/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.3696 - mean_absolute_error: 61.6178 - mean_squared_error: 9119.0694 - val_loss: 0.5348 - val_mean_absolute_error: 131.4929 - val_mean_squared_error: 35635.0846
#
# Epoch 00067: val_loss did not improve from 0.28273
# Epoch 68/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.3451 - mean_absolute_error: 58.9946 - mean_squared_error: 8375.9092 - val_loss: 0.2623 - val_mean_absolute_error: 80.7976 - val_mean_squared_error: 15053.1770
#
# Epoch 00068: val_loss improved from 0.28273 to 0.26231, saving model to Weights-068--0.26231.hdf5
# Epoch 69/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.3749 - mean_absolute_error: 61.8239 - mean_squared_error: 9278.9034 - val_loss: 0.4735 - val_mean_absolute_error: 113.8659 - val_mean_squared_error: 26171.0661
#
# Epoch 00069: val_loss did not improve from 0.26231
# Epoch 70/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.3167 - mean_absolute_error: 57.1302 - mean_squared_error: 7958.6834 - val_loss: 0.4950 - val_mean_absolute_error: 121.2091 - val_mean_squared_error: 28835.3646
#
# Epoch 00070: val_loss did not improve from 0.26231
# Epoch 71/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.2985 - mean_absolute_error: 55.7194 - mean_squared_error: 7657.3289 - val_loss: 0.2856 - val_mean_absolute_error: 87.6380 - val_mean_squared_error: 16249.6833
#
# Epoch 00071: val_loss did not improve from 0.26231
# Epoch 72/100
# 8708/8708 [==============================] - 1s 131us/step - loss: 0.2903 - mean_absolute_error: 54.8020 - mean_squared_error: 7400.4215 - val_loss: 0.3005 - val_mean_absolute_error: 95.5935 - val_mean_squared_error: 19343.5242
#
# Epoch 00072: val_loss did not improve from 0.26231
# Epoch 73/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.2716 - mean_absolute_error: 53.7132 - mean_squared_error: 7072.4110 - val_loss: 0.3283 - val_mean_absolute_error: 83.0457 - val_mean_squared_error: 13242.9808
#
# Epoch 00073: val_loss did not improve from 0.26231
# Epoch 74/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 0.2719 - mean_absolute_error: 54.2150 - mean_squared_error: 7217.7558 - val_loss: 0.2504 - val_mean_absolute_error: 93.5995 - val_mean_squared_error: 18132.2876
#
# Epoch 00074: val_loss improved from 0.26231 to 0.25041, saving model to Weights-074--0.25041.hdf5
# Epoch 75/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.2462 - mean_absolute_error: 51.8315 - mean_squared_error: 6606.9834 - val_loss: 0.4680 - val_mean_absolute_error: 117.3271 - val_mean_squared_error: 27229.4268
#
# Epoch 00075: val_loss did not improve from 0.25041
# Epoch 76/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.2218 - mean_absolute_error: 49.8148 - mean_squared_error: 6088.2112 - val_loss: 0.3387 - val_mean_absolute_error: 98.3054 - val_mean_squared_error: 18961.9617
#
# Epoch 00076: val_loss did not improve from 0.25041
# Epoch 77/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.2196 - mean_absolute_error: 48.9875 - mean_squared_error: 5946.8634 - val_loss: 0.3352 - val_mean_absolute_error: 104.5354 - val_mean_squared_error: 20377.7670
#
# Epoch 00077: val_loss did not improve from 0.25041
# Epoch 78/100
# 8708/8708 [==============================] - 1s 132us/step - loss: 0.2234 - mean_absolute_error: 49.5242 - mean_squared_error: 6056.6772 - val_loss: 0.4672 - val_mean_absolute_error: 109.6986 - val_mean_squared_error: 26761.8064
#
# Epoch 00078: val_loss did not improve from 0.25041
# Epoch 79/100
# 8708/8708 [==============================] - 1s 134us/step - loss: 0.2388 - mean_absolute_error: 50.6001 - mean_squared_error: 6296.3410 - val_loss: 0.4294 - val_mean_absolute_error: 116.6504 - val_mean_squared_error: 26468.2577
#
# Epoch 00079: val_loss did not improve from 0.25041
# Epoch 80/100
# 8708/8708 [==============================] - 1s 135us/step - loss: 0.2150 - mean_absolute_error: 48.9319 - mean_squared_error: 5911.3878 - val_loss: 0.3484 - val_mean_absolute_error: 109.6426 - val_mean_squared_error: 24460.9513
#
# Epoch 00080: val_loss did not improve from 0.25041
# Epoch 81/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.2119 - mean_absolute_error: 48.9329 - mean_squared_error: 5863.7328 - val_loss: 0.2404 - val_mean_absolute_error: 86.7737 - val_mean_squared_error: 15422.0895
#
# Epoch 00081: val_loss improved from 0.25041 to 0.24042, saving model to Weights-081--0.24042.hdf5
# Epoch 82/100
# 8708/8708 [==============================] - 1s 133us/step - loss: 0.2117 - mean_absolute_error: 48.9358 - mean_squared_error: 5779.7224 - val_loss: 0.5264 - val_mean_absolute_error: 119.1060 - val_mean_squared_error: 25029.5363
#
# Epoch 00082: val_loss did not improve from 0.24042
# Epoch 83/100
# 8708/8708 [==============================] - 1s 133us/step - loss: 0.2206 - mean_absolute_error: 49.0711 - mean_squared_error: 5865.2449 - val_loss: 0.2376 - val_mean_absolute_error: 84.9980 - val_mean_squared_error: 15040.4514
#
# Epoch 00083: val_loss improved from 0.24042 to 0.23761, saving model to Weights-083--0.23761.hdf5
# Epoch 84/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.2072 - mean_absolute_error: 48.1007 - mean_squared_error: 5659.0681 - val_loss: 0.3382 - val_mean_absolute_error: 108.0012 - val_mean_squared_error: 21581.4209
#
# Epoch 00084: val_loss did not improve from 0.23761
# Epoch 85/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.2185 - mean_absolute_error: 48.7577 - mean_squared_error: 5909.9317 - val_loss: 0.3009 - val_mean_absolute_error: 99.4984 - val_mean_squared_error: 19000.3511
#
# Epoch 00085: val_loss did not improve from 0.23761
# Epoch 86/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.2134 - mean_absolute_error: 48.8122 - mean_squared_error: 5866.8074 - val_loss: 0.2418 - val_mean_absolute_error: 95.0974 - val_mean_squared_error: 19698.5012
#
# Epoch 00086: val_loss did not improve from 0.23761
# Epoch 87/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.1984 - mean_absolute_error: 47.2047 - mean_squared_error: 5468.7362 - val_loss: 0.2937 - val_mean_absolute_error: 97.3910 - val_mean_squared_error: 18360.9393
#
# Epoch 00087: val_loss did not improve from 0.23761
# Epoch 88/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.1973 - mean_absolute_error: 47.1710 - mean_squared_error: 5502.4428 - val_loss: 0.2986 - val_mean_absolute_error: 107.0538 - val_mean_squared_error: 22758.0801
#
# Epoch 00088: val_loss did not improve from 0.23761
# Epoch 89/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.2082 - mean_absolute_error: 48.0637 - mean_squared_error: 5610.5319 - val_loss: 0.2662 - val_mean_absolute_error: 87.4389 - val_mean_squared_error: 15718.6451
#
# Epoch 00089: val_loss did not improve from 0.23761
# Epoch 90/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.2070 - mean_absolute_error: 47.6629 - mean_squared_error: 5579.5552 - val_loss: 0.4304 - val_mean_absolute_error: 114.3422 - val_mean_squared_error: 25355.2602
#
# Epoch 00090: val_loss did not improve from 0.23761
# Epoch 91/100
# 8708/8708 [==============================] - 1s 123us/step - loss: 0.1934 - mean_absolute_error: 46.5942 - mean_squared_error: 5301.0931 - val_loss: 0.3054 - val_mean_absolute_error: 101.3582 - val_mean_squared_error: 19059.7185
#
# Epoch 00091: val_loss did not improve from 0.23761
# Epoch 92/100
# 8708/8708 [==============================] - 1s 126us/step - loss: 0.2056 - mean_absolute_error: 48.3480 - mean_squared_error: 5729.6372 - val_loss: 0.5887 - val_mean_absolute_error: 128.0241 - val_mean_squared_error: 31951.2505
#
# Epoch 00092: val_loss did not improve from 0.23761
# Epoch 93/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.2023 - mean_absolute_error: 47.4992 - mean_squared_error: 5506.5549 - val_loss: 0.2650 - val_mean_absolute_error: 99.2257 - val_mean_squared_error: 19281.4851
#
# Epoch 00093: val_loss did not improve from 0.23761
# Epoch 94/100
# 8708/8708 [==============================] - 1s 129us/step - loss: 0.1987 - mean_absolute_error: 47.3790 - mean_squared_error: 5535.5607 - val_loss: 0.1835 - val_mean_absolute_error: 78.3282 - val_mean_squared_error: 12674.8944
#
# Epoch 00094: val_loss improved from 0.23761 to 0.18349, saving model to Weights-094--0.18349.hdf5
# Epoch 95/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.1997 - mean_absolute_error: 46.9697 - mean_squared_error: 5427.4925 - val_loss: 0.2359 - val_mean_absolute_error: 92.4706 - val_mean_squared_error: 17158.6828
#
# Epoch 00095: val_loss did not improve from 0.18349
# Epoch 96/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.1921 - mean_absolute_error: 46.4776 - mean_squared_error: 5310.7379 - val_loss: 0.3064 - val_mean_absolute_error: 98.9358 - val_mean_squared_error: 18950.7952
#
# Epoch 00096: val_loss did not improve from 0.18349
# Epoch 97/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.1968 - mean_absolute_error: 46.9088 - mean_squared_error: 5449.9298 - val_loss: 0.2520 - val_mean_absolute_error: 86.1860 - val_mean_squared_error: 14917.7492
#
# Epoch 00097: val_loss did not improve from 0.18349
# Epoch 98/100
# 8708/8708 [==============================] - 1s 127us/step - loss: 0.2083 - mean_absolute_error: 48.9085 - mean_squared_error: 5995.0100 - val_loss: 0.1485 - val_mean_absolute_error: 68.3651 - val_mean_squared_error: 10304.1317
#
# Epoch 00098: val_loss improved from 0.18349 to 0.14847, saving model to Weights-098--0.14847.hdf5
# Epoch 99/100
# 8708/8708 [==============================] - 1s 125us/step - loss: 0.1977 - mean_absolute_error: 47.0475 - mean_squared_error: 5392.0422 - val_loss: 0.1633 - val_mean_absolute_error: 73.1452 - val_mean_squared_error: 11790.3010
#
# Epoch 00099: val_loss did not improve from 0.14847
# Epoch 100/100
# 8708/8708 [==============================] - 1s 128us/step - loss: 0.1966 - mean_absolute_error: 47.1450 - mean_squared_error: 5436.8973 - val_loss: 0.3084 - val_mean_absolute_error: 103.5870 - val_mean_squared_error: 19928.2244
#
# Epoch 00100: val_loss did not improve from 0.14847

# %%
data['count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %%
test=pd.read_csv("test.csv")
test_original=test.copy()

# %%
test.shape
# Out:
# (6493, 9)

# %%
test.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed'],
#       dtype='object')

# %%
test['datetime'] = pd.to_datetime(test['datetime'], errors='coerce')

# %%
test['year'] = test['datetime'].dt.year 
#test['month'] = test['datetime'].dt.month 
test['day'] = test['datetime'].dt.day 
test['hour'] = test['datetime'].dt.hour

# %%
test=test.drop('datetime',axis=1)

# %%
test=normalize(test,["temp","atemp","humidity","windspeed"])

# %%
test = dummy_data(test, ["season","weather","hour"])

# %%
#making predictions
prediction = NN_model.predict(test)

# %%
#prediction=pd.DataFrame(prediction)

#prediction=prediction.clip(lower=0)
#prediction

# %%
prediction.shape
# Out:
# (6493, 1)

# %%
evaluation=test_original['datetime'].to_frame()
evaluation["count"]=prediction
evaluation[:10]
# Out:
#               datetime       count
# 0  2011-01-20 00:00:00   14.246375
# 1  2011-01-20 01:00:00    7.631408
# 2  2011-01-20 02:00:00    4.862448
# 3  2011-01-20 03:00:00    2.840283
# 4  2011-01-20 04:00:00    2.791348
# 5  2011-01-20 05:00:00   13.971608
# 6  2011-01-20 06:00:00   47.233242
# 7  2011-01-20 07:00:00  152.098450
# 8  2011-01-20 08:00:00  262.644135
# 9  2011-01-20 09:00:00  136.051361

# %%
evaluation["count"] = evaluation["count"].astype(int)
evaluation["count"]
# Out:
# 0        14
# 1         7
# 2         4
# 3         2
# 4         2
# 5        13
# 6        47
# 7       152
# 8       262
# 9       136
# 10       69
# 11       74
# 12      107
# 13       86
# 14       79
# 15       84
# 16      119
# 17      259
# 18      203
# 19      141
# 20       91
# 21       68
# 22       49
# 23       32
# 24       12
# 25        5
# 26        3
# 27        2
# 28        2
# 29       12
#        ...
# 6463     99
# 6464    115
# 6465     59
# 6466     51
# 6467     38
# 6468     29
# 6469     13
# 6470      6
# 6471      3
# 6472      2
# 6473      2
# 6474     12
# 6475     45
# 6476    133
# 6477    223
# 6478    131
# 6479     61
# 6480     66
# 6481     80
# 6482     86
# 6483     78
# 6484     85
# 6485    110
# 6486    244
# 6487    222
# 6488    145
# 6489    103
# 6490     90
# 6491     73
# 6492     42
# Name: count, Length: 6493, dtype: int64

# %%
evaluation.to_csv("submissionv7.csv",index=False)
