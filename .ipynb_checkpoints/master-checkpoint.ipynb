# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
import importlib 
module_name = "Bounce assignment shrweta"
x = importlib.import_module(module_name)

# %%
data = x.Load()

# %%
data=x.Transform(data)

# %%
x.Visualize1(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-957182eda267> in <module>
# ----> 1 x.Visualize1(data)
#
# ~\Documents\GitHub\bounce.demo\Bounce assignment shrweta.py in Visualize1(data)
#
# NameError: name 'np' is not defined
